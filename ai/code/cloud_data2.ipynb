# %%
# !pip install netcdf4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.4 MB/s eta 0:00:00
# ...

# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/Shareddrives/미니미니전람회/ai/data/COT.nc'
data1 = nc.Dataset(filename)

# %%
f = '/content/drive/Shareddrives/미니미니전람회/ai/data/CTH.nc'
data2 = nc.Dataset(f)

# %%
f = '/content/drive/Shareddrives/미니미니전람회/ai/data/VI_B.nc'
data3 = nc.Dataset(f)
f = '/content/drive/Shareddrives/미니미니전람회/ai/data/VI_B.nc'
data4 = nc.Dataset('/content/drive/Shareddrives/미니미니전람회/ai/data/IR.nc')

# %%
data3.variables.keys(),data4.variables.keys()
# Out:
# (dict_keys(['image_pixel_values']), dict_keys(['image_pixel_values']))

# %%
vi_b = np.array(data3.variables['image_pixel_values'][:].data)
vi_b
# Out:
# array([[183, 185, 186, ..., 278, 277, 279],
#        [183, 185, 185, ..., 278, 277, 278],
#        [186, 183, 185, ..., 278, 279, 278],
#        ...,
#        [208, 209, 210, ..., 208, 209, 209],
#        [208, 208, 209, ..., 209, 209, 209],
#        [208, 208, 208, ..., 209, 208, 208]], dtype=uint16)

# %%
ir = np.array(data4.variables['image_pixel_values'][:].data)
ir
# Out:
# array([[6216, 6216, 6217, ..., 7222, 7239, 7233],
#        [6212, 6216, 6217, ..., 7242, 7239, 7251],
#        [6212, 6216, 6217, ..., 7242, 7259, 7251],
#        ...,
#        [3959, 3959, 4033, ..., 3791, 3798, 3793],
#        [3956, 3959, 3985, ..., 3791, 3794, 3791],
#        [3957, 3956, 3968, ..., 3793, 3794, 3786]], dtype=uint16)

# %%
np.isnan(vi_b).sum()
# Out:
# 0

# %%
np.isnan(ir).sum()
# Out:
# 0

# %%
c = np.array(data1.variables['COT'][:].data)

# %%
plt.scatter(np.linspace(1,3000,3000),c[100][0:3000])

# %%
cot = np.array(data1.variables['COT'][:].data)
cth = np.array(data2.variables['CTH'][:].data)

# %%
import pandas as pd

# %%
cot_df = pd.DataFrame(cot)
cth_df = pd.DataFrame(cth)

# %%
cot_df
# Out:
#          0        1        2        3        4        5         6        7     \
# 0     65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 1     65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 2     65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 3     65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 4     65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# ...       ...      ...      ...      ...      ...      ...       ...      ...
# 2595  65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 2596  65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 2597  65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 2598  65535.0  65535.0  65535.0  65535.0  65535.0  65535.0  65535.00  65535.0
# 2599  65535.0  65535.0  65535.0  65535.0  65535.0  65535.0      0.51  65535.0
#
# ...

# %%
cth_df
# Out:
#           0         1         2         3         4         5         6     \
# 0         4.79      4.79      4.77  65535.00      4.73  65535.00  65535.00
# 1         4.78      4.79      4.77      4.76      4.73      4.73  65535.00
# 2         4.78      4.79      4.77      4.76      4.76      4.73  65535.00
# 3         4.85      4.79      4.80      4.77      4.76      4.75  65535.00
# 4         4.85      4.91      4.79      4.80      4.76      4.75      3.69
# ...        ...       ...       ...       ...       ...       ...       ...
# 2595  65535.00  65535.00  65535.00  65535.00  65535.00  65535.00  65535.00
# 2596  65535.00  65535.00  65535.00  65535.00  65535.00  65535.00  65535.00
# 2597  65535.00  65535.00  65535.00  65535.00  65535.00      0.20  65535.00
# 2598  65535.00  65535.00  65535.00  65535.00      2.74      0.20      2.94
# 2599  65535.00  65535.00  65535.00      0.00      2.74      2.74      1.39
#
# ...

# %%
cot = np.array(cot_df[cot_df < 1500.00])
cth = np.array(cth_df[cth_df < 16.00])*1000

# %%
# np.nan_to_num(cot,0)
# np.nan_to_num(cth,0)

# %%
cth
# Out:
# array([[4790.    , 4790.    , 4770.    , ..., 8720.    , 8620.    ,
#         8590.    ],
#        [4779.9995, 4790.    , 4770.    , ..., 8630.    , 8620.    ,
#         8670.    ],
#        [4779.9995, 4790.    , 4770.    , ..., 8630.    , 8780.    ,
#         8670.    ],
#        ...,
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan]], dtype=float32)

# %%
cot
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %%
cth.shape
# Out:
# (2600, 3000)

# %%
cot.shape
# Out:
# (2600, 3000)

# %%
plt.imshow(cot)

# %%
plt.imshow(cth)

# %%
clh = cth - cot

# %%
clh[1000][1000]
# Out:
# 4076.78

# %%
cth.max(),cot.max()
# Out:
# (nan, nan)

# %%
ax= plt.figure().add_subplot(projection = '3d')

# %%
ax= plt.figure().add_subplot(projection = '3d')
a = 100
b = 100
for i in range(a):
    ax.scatter(np.linspace(1,b,b),i,clh[i][0:b], c='white', alpha=0.5, edgecolors='skyblue', linewidths=0.1)
    ax.scatter(np.linspace(1,b,b),i,cth[i][0:b], c='gray', alpha=0.5, edgecolors='skyblue', linewidth=0.1)

# %%
ax.view_init(30,60)

# %%
plt.imshow(vi_b)

# %%
plt.imshow(ir)

# %%
cth.min(), cot.min()
# Out:
# (nan, nan)

# %%
clh.max(), clh.min()
# Out:
# (nan, nan)

# %%
cot_nonnull = cot[~np.isnan(cot)]
cot_nonnull.shape
# Out:
# (2229470,)

# %%
cth_nonnull = cth[~np.isnan(cot)]
cth_nonnull.shape

# %%
vi_b.shape
# Out:
# (5200, 6000)

# %%
ir.shape

# %%
vi_b
# Out:
# array([[183, 185, 186, ..., 278, 277, 279],
#        [183, 185, 185, ..., 278, 277, 278],
#        [186, 183, 185, ..., 278, 279, 278],
#        ...,
#        [208, 209, 210, ..., 208, 209, 209],
#        [208, 208, 209, ..., 209, 209, 209],
#        [208, 208, 208, ..., 209, 208, 208]], dtype=uint16)

# %%
vi_b_nonnull = np.zeros((2600, 3000), 'float64')
vi_b_nonnull.shape
# Out:
# (2600, 3000)

# %%
lat = np.zeros((2600, 3000), 'float64')
log = np.zeros((2600, 3000), 'float64')

# %%
for i in range(0, 5200, 2):
    for j in range(0, 6000, 2):
        value = (vi_b[i][j] + vi_b[i][j + 1] + vi_b[i + 1][j] + vi_b[i + 1][j + 1]) / 4
        vi_b_nonnull[int(i / 2)][int(j / 2)] = value
        lat[int(i / 2)][int(j / 2)] = int(i/2)
        log[int(i / 2)][int(j / 2)] = int(j/2)
vi_b_nonnull
# Out:
# array([[184.  , 185.75, 187.  , ..., 276.5 , 278.  , 277.75],
#        [184.75, 185.  , 186.75, ..., 277.75, 278.25, 278.5 ],
#        [185.25, 184.25, 185.  , ..., 277.75, 279.5 , 278.75],
#        ...,
#        [209.  , 209.25, 213.  , ..., 208.75, 210.  , 209.25],
#        [208.75, 209.75, 210.25, ..., 208.25, 209.25, 209.  ],
#        [208.  , 208.5 , 210.25, ..., 208.5 , 209.  , 208.5 ]])

# %%
log = log[~np.isnan(cot)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-d3de3ced3eab> in <cell line: 1>()
# ----> 1 log = log[~np.isnan(cot)]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
log
# Out:
# array([2375., 2374., 2375., ..., 2957., 2973., 2974.])

# %%
log = log.reshape(-1,1)

# %%
log.shape
# Out:
# (2229470, 1)

# %%
vi_b_nonnull_2D = vi_b_nonnull
plt.imshow(vi_b_nonnull_2D)
plt.show()

# %%
vi_b_nonnull.shape
# Out:
# (2600, 3000)

# %%
vi_b_nonnull = vi_b_nonnull[~np.isnan(cot)]

# %%
lat = lat[~np.isnan(cot)]

# %%
ir_nonnull = ir[~np.isnan(cot)]

# %%
vi_b_nonnull.shape
# Out:
# (2229470,)

# %%
ir_nonnull.shape
# Out:
# (2229470,)

# %%
lat.shape
# Out:
# (2229470,)

# %%
plt.imshow(vi_b_nonnull)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-2f5f52dbdd21> in <cell line: 1>()
# ----> 1 plt.imshow(vi_b_nonnull)
#       2
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %% [markdown]
# # Model

# %%
import numpy as np

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Sequential

# %%
vi_b_nonnull = vi_b_nonnull.reshape(-1, 1)
vi_b_nonnull
# Out:
# array([[329. ],
#        [341. ],
#        [342. ],
#        ...,
#        [255.5],
#        [259. ],
#        [242.5]])

# %%
ir_nonnull =ir_nonnull.reshape(-1,1)

# %%
cot_nonnull = cot_nonnull.reshape(-1, 1)
cth_nonnull = cth_nonnull.reshape(-1, 1)

# %%
cot_nonnull
# Out:
# array([[0.26     ],
#        [0.26     ],
#        [0.26     ],
#        ...,
#        [2.32     ],
#        [1.8499999],
#        [1.8499999]], dtype=float32)

# %%
cth_nonnull
# Out:
# array([[5370.     ],
#        [5549.9995 ],
#        [5370.     ],
#        ...,
#        [1390.     ],
#        [ 729.99994],
#        [ 729.99994]], dtype=float32)

# %%
log.shape
# Out:
# (2229470, 1)

# %%
x = np.column_stack((np.column_stack((np.column_stack((ir_nonnull, vi_b_nonnull)),lat)),log))
y = np.column_stack((cth_nonnull, cot_nonnull))

# %%
"""y = y[60000:60300][:]
y.shape"""
# Out:
# 'y = y[60000:60300][:]\ny.shape'

# %%
"""x = x[60000:60300][:]
x.shape"""
# Out:
# 'x = x[60000:60300][:]\nx.shape'

# %%
x
# Out:
# array([[6882. ,  329. ,  106. , 2375. ],
#        [6811. ,  341. ,  107. , 2374. ],
#        [6882. ,  342. ,  107. , 2375. ],
#        ...,
#        [4394. ,  255.5, 2599. , 2957. ],
#        [4243. ,  259. , 2599. , 2973. ],
#        [4243. ,  242.5, 2599. , 2974. ]])

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_target, test_target = train_test_split(x, y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(train_data,train_target,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept = True)
model.fit(train_data,train_target)
w = model.coef_
b = model.intercept_
print(w,b)
# Out:
# [[ 4.39883885e+00 -2.64564621e+00  4.58404356e+00  5.77210471e-01]
#  [-2.07818837e-03  7.80608798e-02  2.54476316e-03  3.93684626e-04]] [-2.74127637e+04 -2.33785994e+01]

# %%
model.score(test_data,test_target)
# Out:
# 0.6991691694817979

# %%
model = Sequential()

# %%
model.add(Dense(64,input_dim = 4, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='relu'))
model.compile(optimizer='adam', loss='mse', metrics='accuracy')

# %%
train_data.shape, train_target.shape
# Out:
# ((1672102, 4), (1672102, 2))

# %%
plt.scatter(x[:,0],y[:,0])

# %%
# Out:
# 6237.0

# %%
model.fit(train_data,train_target,epochs=20)
# Out:
# Epoch 1/20
#  3662/52254 [=>............................] - ETA: 3:48 - loss: 2680754.5000 - accuracy: 0.9434
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-cf88c8c76e07> in <cell line: 1>()
# ----> 1 model.fit(train_data,train_target,epochs=20)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
model.evaluate(test_data, test_target)

# %%
pred = model.predict(test_data)
# Out:
# 17418/17418 [==============================] - 36s 2ms/step
